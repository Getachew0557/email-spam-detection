# %% [markdown]
# ## Data Collection

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from collections import defaultdict

# %% [markdown]
# ### Load Data

# %%
# Load the dataset
data = pd.read_csv('../data/SMSSpamCollection', sep='\t', header=None, names=['label', 'message'])
data.columns = ['label', 'message']
data['label'] = data['label'].map({'ham': 0, 'spam': 1})

# %% [markdown]
# ## Data Preprocessing

# %%
data.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
print(data.head())
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Train Test Split

# %%
# Split dataset into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Preprocessing
def preprocess_text(text):
    return text.lower().split()

train_data['processed'] = train_data['message'].apply(preprocess_text)
test_data['processed'] = test_data['message'].apply(preprocess_text)

# %%
train_data['processed']
# Out:
# 1978    [reply, to, win, £100, weekly!, where, will, t...
# 3989    [hello., sort, of, out, in, town, already., th...
# 3935    [how, come, guoyang, go, n, tell, her?, then, ...
# 4078    [hey, sathya, till, now, we, dint, meet, not, ...
# 4086    [orange, brings, you, ringtones, from, all, ti...
#                               ...
# 3772    [hi,, wlcome, back,, did, wonder, if, you, got...
# 5191                          [sorry,, i'll, call, later]
# 5226    [prabha..i'm, soryda..realy..frm, heart, i'm, ...
# 5390                     [nt, joking, seriously, i, told]
# 860      [did, he, just, say, somebody, is, named, tampa]
# Name: processed, Length: 4457, dtype: object

# %%
test_data['processed']
# Out:
# 3245    [squeeeeeze!!, this, is, christmas, hug.., if,...
# 944     [and, also, i've, sorta, blown, him, off, a, c...
# 1044    [mmm, thats, better, now, i, got, a, roast, do...
# 2484    [mm, have, some, kanji, dont, eat, anything, h...
# 812     [so, there's, a, ring, that, comes, with, the,...
#                               ...
# 4264    [den, only, weekdays, got, special, price..., ...
# 2439    [i, not, busy, juz, dun, wan, 2, go, so, early...
# 5556    [yes, i, have., so, that's, why, u, texted., p...
# 4205    [how, are, you, enjoying, this, semester?, tak...
# 4293                                              [g.w.r]
# Name: processed, Length: 1115, dtype: object

# %%
# Vocabulary and word counts
spam_word_counts = defaultdict(int)
ham_word_counts = defaultdict(int)
spam_total = ham_total = 0

for _, row in train_data.iterrows():
    for word in row['processed']:
        if row['label'] == 1:  # Spam
            spam_word_counts[word] += 1
            spam_total += 1
        else:  # Ham
            ham_word_counts[word] += 1
            ham_total += 1

# Prior probabilities
P_spam = len(train_data[train_data['label'] == 1]) / len(train_data)
P_ham = 1 - P_spam

# %%
# Prior probabilities
P_spam = len(train_data[train_data['label'] == 1]) / len(train_data)
P_ham = 1 - P_spam
print(f"Priors:\nP(spam) = {P_spam:.4f}\nP(ham) = {P_ham:.4f}\n")
# Out:
# Priors:
# P(spam) = 0.1342
# P(ham) = 0.8658

# %%
# Laplace smoothing
vocab = set(spam_word_counts.keys()).union(set(ham_word_counts.keys()))
vocab_size = len(vocab)

def calculate_word_probability(word, label):
    if label == 1:  # Spam
        likelihood = (spam_word_counts[word] + 1) / (spam_total + vocab_size)
    else:  # Ham
        likelihood = (ham_word_counts[word] + 1) / (ham_total + vocab_size)
    print(f"Likelihood of '{word}' given {'spam' if label == 1 else 'ham'}: {likelihood:.6f}")
    return likelihood

# %%
# Predict
def predict(message):
    words = preprocess_text(message)
    spam_prob = np.log(P_spam)
    ham_prob = np.log(P_ham)
    
    for word in words:
        spam_prob += np.log(calculate_word_probability(word, 1))
        ham_prob += np.log(calculate_word_probability(word, 0))
    
    posterior_spam = np.exp(spam_prob) / (np.exp(spam_prob) + np.exp(ham_prob))
    posterior_ham = np.exp(ham_prob) / (np.exp(spam_prob) + np.exp(ham_prob))
    
    print(f"Posterior probabilities for message '{message}':")
    print(f"P(spam|message) = {posterior_spam:.6f}")
    print(f"P(ham|message) = {posterior_ham:.6f}\n")
    
    return 1 if spam_prob > ham_prob else 0

# %%
# Evaluate
test_data['predicted'] = test_data['message'].apply(predict)

# Calculate Metrics
accuracy = (test_data['label'] == test_data['predicted']).mean()
precision = precision_score(test_data['label'], test_data['predicted'])
recall = recall_score(test_data['label'], test_data['predicted'])
f1 = f1_score(test_data['label'], test_data['predicted'])

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Likelihood of 'squeeeeeze!!' given spam: 0.000038
# Likelihood of 'squeeeeeze!!' given ham: 0.000015
# Likelihood of 'this' given spam: 0.002528
# Likelihood of 'this' given ham: 0.002744
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'christmas' given spam: 0.000077
# Likelihood of 'christmas' given ham: 0.000075
# Likelihood of 'hug..' given spam: 0.000038
# Likelihood of 'hug..' given ham: 0.000015
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'lik' given spam: 0.000038
# Likelihood of 'lik' given ham: 0.000075
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'frndshp' given spam: 0.000038
# Likelihood of 'frndshp' given ham: 0.000015
# Likelihood of 'den' given spam: 0.000038
# Likelihood of 'den' given ham: 0.000358
# Likelihood of 'hug' given spam: 0.000038
# Likelihood of 'hug' given ham: 0.000030
# Likelihood of 'me' given spam: 0.000690
# Likelihood of 'me' given ham: 0.007204
# Likelihood of 'back..' given spam: 0.000038
# Likelihood of 'back..' given ham: 0.000015
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'get' given spam: 0.002490
# Likelihood of 'get' given ham: 0.003624
# Likelihood of '3' given spam: 0.000613
# Likelihood of '3' given ham: 0.000403
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'r' given spam: 0.000766
# Likelihood of 'r' given ham: 0.001477
# Likelihood of 'cute:)' given spam: 0.000038
# Likelihood of 'cute:)' given ham: 0.000015
# Likelihood of '6' given spam: 0.000153
# Likelihood of '6' given ham: 0.000179
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'r' given spam: 0.000766
# Likelihood of 'r' given ham: 0.001477
# Likelihood of 'luvd:*' given spam: 0.000038
# Likelihood of 'luvd:*' given ham: 0.000015
# Likelihood of '9' given spam: 0.000038
# Likelihood of '9' given ham: 0.000149
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'r' given spam: 0.000766
# Likelihood of 'r' given ham: 0.001477
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'lucky;)' given spam: 0.000038
# Likelihood of 'lucky;)' given ham: 0.000015
# Likelihood of 'none?' given spam: 0.000038
# Likelihood of 'none?' given ham: 0.000015
# Likelihood of 'people' given spam: 0.000153
# Likelihood of 'people' given ham: 0.000492
# Likelihood of 'hate' given spam: 0.000038
# Likelihood of 'hate' given ham: 0.000060
# Likelihood of 'u:' given spam: 0.000038
# Likelihood of 'u:' given ham: 0.000030
# Posterior probabilities for message 'Squeeeeeze!! This is christmas hug.. If u lik my frndshp den hug me back.. If u get 3 u r cute:) 6 u r luvd:* 9 u r so lucky;) None? People hate u:':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'and' given spam: 0.003754
# Likelihood of 'and' given ham: 0.010112
# Likelihood of 'also' given spam: 0.000077
# Likelihood of 'also' given ham: 0.000716
# Likelihood of 'i've' given spam: 0.000038
# Likelihood of 'i've' given ham: 0.000805
# Likelihood of 'sorta' given spam: 0.000038
# Likelihood of 'sorta' given ham: 0.000015
# Likelihood of 'blown' given spam: 0.000038
# Likelihood of 'blown' given ham: 0.000015
# Likelihood of 'him' given spam: 0.000077
# Likelihood of 'him' given ham: 0.001014
# Likelihood of 'off' given spam: 0.000038
# Likelihood of 'off' given ham: 0.000612
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'couple' given spam: 0.000077
# Likelihood of 'couple' given ham: 0.000119
# Likelihood of 'times' given spam: 0.000038
# Likelihood of 'times' given ham: 0.000209
# Likelihood of 'recently' given spam: 0.000115
# Likelihood of 'recently' given ham: 0.000030
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'id' given spam: 0.000077
# Likelihood of 'id' given ham: 0.000149
# Likelihood of 'rather' given spam: 0.000038
# Likelihood of 'rather' given ham: 0.000060
# Likelihood of 'not' given spam: 0.000690
# Likelihood of 'not' given ham: 0.004907
# Likelihood of 'text' given spam: 0.003486
# Likelihood of 'text' given ham: 0.000805
# Likelihood of 'him' given spam: 0.000077
# Likelihood of 'him' given ham: 0.001014
# Likelihood of 'out' given spam: 0.001303
# Likelihood of 'out' given ham: 0.001805
# Likelihood of 'of' given spam: 0.002950
# Likelihood of 'of' given ham: 0.006130
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'blue' given spam: 0.000038
# Likelihood of 'blue' given ham: 0.000104
# Likelihood of 'looking' given spam: 0.000230
# Likelihood of 'looking' given ham: 0.000194
# Likelihood of 'for' given spam: 0.006206
# Likelihood of 'for' given ham: 0.005891
# Likelihood of 'weed' given spam: 0.000038
# Likelihood of 'weed' given ham: 0.000045
# Posterior probabilities for message 'And also I've sorta blown him off a couple times recently so id rather not text him out of the blue looking for weed':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'mmm' given spam: 0.000038
# Likelihood of 'mmm' given ham: 0.000060
# Likelihood of 'thats' given spam: 0.000038
# Likelihood of 'thats' given ham: 0.000507
# Likelihood of 'better' given spam: 0.000038
# Likelihood of 'better' given ham: 0.000343
# Likelihood of 'now' given spam: 0.003141
# Likelihood of 'now' given ham: 0.001760
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'got' given spam: 0.000306
# Likelihood of 'got' given ham: 0.002774
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'roast' given spam: 0.000038
# Likelihood of 'roast' given ham: 0.000030
# Likelihood of 'down' given spam: 0.000038
# Likelihood of 'down' given ham: 0.000641
# Likelihood of 'me!' given spam: 0.000038
# Likelihood of 'me!' given ham: 0.000045
# Likelihood of 'id' given spam: 0.000038
# Likelihood of 'id' given ham: 0.000030
# Likelihood of 'b' given spam: 0.000345
# Likelihood of 'b' given ham: 0.000656
# Likelihood of 'better' given spam: 0.000038
# Likelihood of 'better' given ham: 0.000343
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'had' given spam: 0.000575
# Likelihood of 'had' given ham: 0.000999
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'few' given spam: 0.000038
# Likelihood of 'few' given ham: 0.000462
# Likelihood of 'drinks' given spam: 0.000115
# Likelihood of 'drinks' given ham: 0.000030
# Likelihood of 'down' given spam: 0.000038
# Likelihood of 'down' given ham: 0.000641
# Likelihood of 'me' given spam: 0.000690
# Likelihood of 'me' given ham: 0.007204
# Likelihood of '2!' given spam: 0.000038
# Likelihood of '2!' given ham: 0.000045
# Likelihood of 'good' given spam: 0.000421
# Likelihood of 'good' given ham: 0.002178
# Likelihood of 'indian?' given spam: 0.000038
# Likelihood of 'indian?' given ham: 0.000015
# Posterior probabilities for message 'Mmm thats better now i got a roast down me! id b better if i had a few drinks down me 2! Good indian?':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'mm' given spam: 0.000038
# Likelihood of 'mm' given ham: 0.000119
# Likelihood of 'have' given spam: 0.003754
# Likelihood of 'have' given ham: 0.005265
# Likelihood of 'some' given spam: 0.000230
# Likelihood of 'some' given ham: 0.001223
# Likelihood of 'kanji' given spam: 0.000038
# Likelihood of 'kanji' given ham: 0.000015
# Likelihood of 'dont' given spam: 0.000306
# Likelihood of 'dont' given ham: 0.001521
# Likelihood of 'eat' given spam: 0.000038
# Likelihood of 'eat' given ham: 0.000373
# Likelihood of 'anything' given spam: 0.000038
# Likelihood of 'anything' given ham: 0.000656
# Likelihood of 'heavy' given spam: 0.000038
# Likelihood of 'heavy' given ham: 0.000075
# Likelihood of 'ok' given spam: 0.000192
# Likelihood of 'ok' given ham: 0.001939
# Posterior probabilities for message 'Mm have some kanji dont eat anything heavy ok':
# P(spam|message) = 0.000001
# P(ham|message) = 0.999999
#
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'there's' given spam: 0.000153
# Likelihood of 'there's' given ham: 0.000239
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'ring' given spam: 0.000192
# Likelihood of 'ring' given ham: 0.000164
# Likelihood of 'that' given spam: 0.000766
# Likelihood of 'that' given ham: 0.005131
# Likelihood of 'comes' given spam: 0.000153
# Likelihood of 'comes' given ham: 0.000194
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'guys' given spam: 0.000153
# Likelihood of 'guys' given ham: 0.000298
# Likelihood of 'costumes.' given spam: 0.000038
# Likelihood of 'costumes.' given ham: 0.000015
# Likelihood of 'it's' given spam: 0.000153
# Likelihood of 'it's' given ham: 0.001119
# Likelihood of 'there' given spam: 0.000345
# Likelihood of 'there' given ham: 0.001611
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'they' given spam: 0.000498
# Likelihood of 'they' given ham: 0.001238
# Likelihood of 'can' given spam: 0.000996
# Likelihood of 'can' given ham: 0.004430
# Likelihood of 'gift' given spam: 0.000536
# Likelihood of 'gift' given ham: 0.000075
# Likelihood of 'their' given spam: 0.000077
# Likelihood of 'their' given ham: 0.000104
# Likelihood of 'future' given spam: 0.000115
# Likelihood of 'future' given ham: 0.000030
# Likelihood of 'yowifes.' given spam: 0.000038
# Likelihood of 'yowifes.' given ham: 0.000015
# Likelihood of 'hint' given spam: 0.000038
# Likelihood of 'hint' given ham: 0.000030
# Likelihood of 'hint' given spam: 0.000038
# Likelihood of 'hint' given ham: 0.000030
# Posterior probabilities for message 'So there's a ring that comes with the guys costumes. It's there so they can gift their future yowifes. Hint hint':
# P(spam|message) = 0.000042
# P(ham|message) = 0.999958
#
# Likelihood of 'sary' given spam: 0.000038
# Likelihood of 'sary' given ham: 0.000015
# Likelihood of 'just' given spam: 0.002222
# Likelihood of 'just' given ham: 0.003535
# Likelihood of 'need' given spam: 0.000345
# Likelihood of 'need' given ham: 0.001879
# Likelihood of 'tim' given spam: 0.000038
# Likelihood of 'tim' given ham: 0.000015
# Likelihood of 'in' given spam: 0.002145
# Likelihood of 'in' given ham: 0.009292
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'bollox' given spam: 0.000038
# Likelihood of 'bollox' given ham: 0.000015
# Likelihood of '&it' given spam: 0.000038
# Likelihood of '&it' given ham: 0.000015
# Likelihood of 'hurt' given spam: 0.000038
# Likelihood of 'hurt' given ham: 0.000239
# Likelihood of 'him' given spam: 0.000077
# Likelihood of 'him' given ham: 0.001014
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'lot' given spam: 0.000038
# Likelihood of 'lot' given ham: 0.000268
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'he' given spam: 0.000038
# Likelihood of 'he' given ham: 0.001999
# Likelihood of 'tol' given spam: 0.000038
# Likelihood of 'tol' given ham: 0.000015
# Likelihood of 'me!' given spam: 0.000038
# Likelihood of 'me!' given ham: 0.000045
# Posterior probabilities for message 'Sary just need Tim in the bollox &it hurt him a lot so he tol me!':
# P(spam|message) = 0.000001
# P(ham|message) = 0.999999
#
# Likelihood of 'love' given spam: 0.000345
# Likelihood of 'love' given ham: 0.001924
# Likelihood of 'isn't' given spam: 0.000038
# Likelihood of 'isn't' given ham: 0.000134
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'decision,' given spam: 0.000038
# Likelihood of 'decision,' given ham: 0.000030
# Likelihood of 'it's' given spam: 0.000153
# Likelihood of 'it's' given ham: 0.001119
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'feeling.' given spam: 0.000038
# Likelihood of 'feeling.' given ham: 0.000030
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'we' given spam: 0.001532
# Likelihood of 'we' given ham: 0.003684
# Likelihood of 'could' given spam: 0.000230
# Likelihood of 'could' given ham: 0.000641
# Likelihood of 'decide' given spam: 0.000038
# Likelihood of 'decide' given ham: 0.000089
# Likelihood of 'who' given spam: 0.001188
# Likelihood of 'who' given ham: 0.000716
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'love,' given spam: 0.000038
# Likelihood of 'love,' given ham: 0.000119
# Likelihood of 'then,' given spam: 0.000038
# Likelihood of 'then,' given ham: 0.000060
# Likelihood of 'life' given spam: 0.000153
# Likelihood of 'life' given ham: 0.000582
# Likelihood of 'would' given spam: 0.000153
# Likelihood of 'would' given ham: 0.000746
# Likelihood of 'be' given spam: 0.001686
# Likelihood of 'be' given ham: 0.004057
# Likelihood of 'much' given spam: 0.000077
# Likelihood of 'much' given ham: 0.001059
# Likelihood of 'simpler,' given spam: 0.000038
# Likelihood of 'simpler,' given ham: 0.000030
# Likelihood of 'but' given spam: 0.000268
# Likelihood of 'but' given ham: 0.004922
# Likelihood of 'then' given spam: 0.000230
# Likelihood of 'then' given ham: 0.002222
# Likelihood of 'less' given spam: 0.000038
# Likelihood of 'less' given ham: 0.000134
# Likelihood of 'magical' given spam: 0.000038
# Likelihood of 'magical' given ham: 0.000045
# Posterior probabilities for message 'Love isn't a decision, it's a feeling. If we could decide who to love, then, life would be much simpler, but then less magical':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'supervisor' given spam: 0.000038
# Likelihood of 'supervisor' given ham: 0.000030
# Likelihood of 'find' given spam: 0.000613
# Likelihood of 'find' given ham: 0.000552
# Likelihood of '4' given spam: 0.003180
# Likelihood of '4' given ham: 0.002058
# Likelihood of 'me' given spam: 0.000690
# Likelihood of 'me' given ham: 0.007204
# Likelihood of 'one' given spam: 0.000268
# Likelihood of 'one' given ham: 0.001715
# Likelihood of 'lor' given spam: 0.000038
# Likelihood of 'lor' given ham: 0.000313
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'thk' given spam: 0.000038
# Likelihood of 'thk' given ham: 0.000582
# Likelihood of 'his' given spam: 0.000077
# Likelihood of 'his' given ham: 0.000731
# Likelihood of 'students.' given spam: 0.000038
# Likelihood of 'students.' given ham: 0.000015
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'havent' given spam: 0.000038
# Likelihood of 'havent' given ham: 0.000283
# Likelihood of 'ask' given spam: 0.000038
# Likelihood of 'ask' given ham: 0.000955
# Likelihood of 'her' given spam: 0.000306
# Likelihood of 'her' given ham: 0.001238
# Likelihood of 'yet.' given spam: 0.000077
# Likelihood of 'yet.' given ham: 0.000134
# Likelihood of 'tell' given spam: 0.000460
# Likelihood of 'tell' given ham: 0.001521
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'aft' given spam: 0.000038
# Likelihood of 'aft' given ham: 0.000224
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'ask' given spam: 0.000038
# Likelihood of 'ask' given ham: 0.000955
# Likelihood of 'her.' given spam: 0.000038
# Likelihood of 'her.' given ham: 0.000134
# Posterior probabilities for message 'My supervisor find 4 me one lor i thk his students. I havent ask her yet. Tell u aft i ask her.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'dear' given spam: 0.000460
# Likelihood of 'dear' given ham: 0.000880
# Likelihood of 'good' given spam: 0.000421
# Likelihood of 'good' given ham: 0.002178
# Likelihood of 'morning' given spam: 0.000038
# Likelihood of 'morning' given ham: 0.000522
# Likelihood of 'now' given spam: 0.003141
# Likelihood of 'now' given ham: 0.001760
# Likelihood of 'only' given spam: 0.001954
# Likelihood of 'only' given ham: 0.001313
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'am' given spam: 0.000421
# Likelihood of 'am' given ham: 0.002461
# Likelihood of 'up' given spam: 0.000613
# Likelihood of 'up' given ham: 0.003013
# Posterior probabilities for message 'Dear good morning now only i am up':
# P(spam|message) = 0.000005
# P(ham|message) = 0.999995
#
# Likelihood of 'i'm' given spam: 0.000268
# Likelihood of 'i'm' given ham: 0.004549
# Likelihood of 'in' given spam: 0.002145
# Likelihood of 'in' given ham: 0.009292
# Likelihood of 'chennai' given spam: 0.000038
# Likelihood of 'chennai' given ham: 0.000104
# Likelihood of 'velachery:)' given spam: 0.000038
# Likelihood of 'velachery:)' given ham: 0.000015
# Posterior probabilities for message 'I'm in chennai velachery:)':
# P(spam|message) = 0.001984
# P(ham|message) = 0.998016
#
# Likelihood of 'lol' given spam: 0.000038
# Likelihood of 'lol' given ham: 0.000671
# Likelihood of 'grr' given spam: 0.000038
# Likelihood of 'grr' given ham: 0.000015
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'mom' given spam: 0.000038
# Likelihood of 'mom' given ham: 0.000104
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'taking' given spam: 0.000038
# Likelihood of 'taking' given ham: 0.000224
# Likelihood of 'forever' given spam: 0.000038
# Likelihood of 'forever' given ham: 0.000045
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'prescription.' given spam: 0.000038
# Likelihood of 'prescription.' given ham: 0.000015
# Likelihood of 'pharmacy' given spam: 0.000038
# Likelihood of 'pharmacy' given ham: 0.000015
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'like' given spam: 0.000498
# Likelihood of 'like' given ham: 0.002580
# Likelihood of '2' given spam: 0.005287
# Likelihood of '2' given ham: 0.003386
# Likelihood of 'minutes' given spam: 0.000230
# Likelihood of 'minutes' given ham: 0.000254
# Likelihood of 'away.' given spam: 0.000038
# Likelihood of 'away.' given ham: 0.000015
# Likelihood of 'ugh.' given spam: 0.000038
# Likelihood of 'ugh.' given ham: 0.000030
# Posterior probabilities for message 'Lol grr my mom is taking forever with my prescription. Pharmacy is like 2 minutes away. Ugh.':
# P(spam|message) = 0.000003
# P(ham|message) = 0.999997
#
# Likelihood of 'no' given spam: 0.001034
# Likelihood of 'no' given ham: 0.002655
# Likelihood of 'other' given spam: 0.000077
# Likelihood of 'other' given ham: 0.000462
# Likelihood of 'valentines' given spam: 0.000115
# Likelihood of 'valentines' given ham: 0.000075
# Likelihood of 'huh?' given spam: 0.000038
# Likelihood of 'huh?' given ham: 0.000075
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'proof' given spam: 0.000038
# Likelihood of 'proof' given ham: 0.000045
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'on' given spam: 0.004482
# Likelihood of 'on' given ham: 0.004549
# Likelihood of 'your' given spam: 0.008198
# Likelihood of 'your' given ham: 0.004967
# Likelihood of 'fb' given spam: 0.000038
# Likelihood of 'fb' given ham: 0.000030
# Likelihood of 'page.' given spam: 0.000038
# Likelihood of 'page.' given ham: 0.000015
# Likelihood of 'ugh' given spam: 0.000038
# Likelihood of 'ugh' given ham: 0.000119
# Likelihood of 'i'm' given spam: 0.000268
# Likelihood of 'i'm' given ham: 0.004549
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'glad' given spam: 0.000038
# Likelihood of 'glad' given ham: 0.000089
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'really' given spam: 0.000077
# Likelihood of 'really' given ham: 0.000940
# Likelihood of 'didn't' given spam: 0.000038
# Likelihood of 'didn't' given ham: 0.000537
# Likelihood of 'watch' given spam: 0.000038
# Likelihood of 'watch' given ham: 0.000388
# Likelihood of 'your' given spam: 0.008198
# Likelihood of 'your' given ham: 0.004967
# Likelihood of 'rupaul' given spam: 0.000038
# Likelihood of 'rupaul' given ham: 0.000015
# Likelihood of 'show' given spam: 0.000192
# Likelihood of 'show' given ham: 0.000194
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'tool!' given spam: 0.000038
# Likelihood of 'tool!' given ham: 0.000015
# Posterior probabilities for message 'No other Valentines huh? The proof is on your fb page. Ugh I'm so glad I really DIDN'T watch your rupaul show you TOOL!':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'i'm' given spam: 0.000268
# Likelihood of 'i'm' given ham: 0.004549
# Likelihood of 'wif' given spam: 0.000038
# Likelihood of 'wif' given ham: 0.000328
# Likelihood of 'him' given spam: 0.000077
# Likelihood of 'him' given ham: 0.001014
# Likelihood of 'now' given spam: 0.003141
# Likelihood of 'now' given ham: 0.001760
# Likelihood of 'buying' given spam: 0.000038
# Likelihood of 'buying' given ham: 0.000104
# Likelihood of 'tix' given spam: 0.000038
# Likelihood of 'tix' given ham: 0.000015
# Likelihood of 'lar...' given spam: 0.000038
# Likelihood of 'lar...' given ham: 0.000209
# Posterior probabilities for message 'I'm wif him now buying tix lar...':
# P(spam|message) = 0.000025
# P(ham|message) = 0.999975
#
# Likelihood of 'er,' given spam: 0.000038
# Likelihood of 'er,' given ham: 0.000030
# Likelihood of 'hello,' given spam: 0.000038
# Likelihood of 'hello,' given ham: 0.000119
# Likelihood of 'things' given spam: 0.000077
# Likelihood of 'things' given ham: 0.000433
# Likelihood of 'didn‘t' given spam: 0.000038
# Likelihood of 'didn‘t' given ham: 0.000030
# Likelihood of 'quite' given spam: 0.000038
# Likelihood of 'quite' given ham: 0.000403
# Likelihood of 'go' given spam: 0.000881
# Likelihood of 'go' given ham: 0.002894
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'plan' given spam: 0.000038
# Likelihood of 'plan' given ham: 0.000254
# Likelihood of '–' given spam: 0.000038
# Likelihood of '–' given ham: 0.000134
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'limping' given spam: 0.000038
# Likelihood of 'limping' given ham: 0.000015
# Likelihood of 'slowly' given spam: 0.000038
# Likelihood of 'slowly' given ham: 0.000089
# Likelihood of 'home' given spam: 0.000115
# Likelihood of 'home' given ham: 0.001372
# Likelihood of 'followed' given spam: 0.000115
# Likelihood of 'followed' given ham: 0.000015
# Likelihood of 'by' given spam: 0.001188
# Likelihood of 'by' given ham: 0.001700
# Likelihood of 'aa' given spam: 0.000038
# Likelihood of 'aa' given ham: 0.000015
# Likelihood of 'and' given spam: 0.003754
# Likelihood of 'and' given ham: 0.010112
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'exhaust' given spam: 0.000038
# Likelihood of 'exhaust' given ham: 0.000030
# Likelihood of 'hanging' given spam: 0.000038
# Likelihood of 'hanging' given ham: 0.000030
# Likelihood of 'off' given spam: 0.000038
# Likelihood of 'off' given ham: 0.000612
# Posterior probabilities for message 'Er, hello, things didn‘t quite go to plan – is limping slowly home followed by aa and with exhaust hanging off':
# P(spam|message) = 0.000001
# P(ham|message) = 0.999999
#
# Likelihood of 'free' given spam: 0.005861
# Likelihood of 'free' given ham: 0.000612
# Likelihood of 'ringtone' given spam: 0.000805
# Likelihood of 'ringtone' given ham: 0.000015
# Likelihood of 'text' given spam: 0.003486
# Likelihood of 'text' given ham: 0.000805
# Likelihood of 'first' given spam: 0.000230
# Likelihood of 'first' given ham: 0.000552
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of '87131' given spam: 0.000038
# Likelihood of '87131' given ham: 0.000015
# Likelihood of 'for' given spam: 0.006206
# Likelihood of 'for' given ham: 0.005891
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'poly' given spam: 0.000498
# Likelihood of 'poly' given ham: 0.000015
# Likelihood of 'or' given spam: 0.006168
# Likelihood of 'or' given ham: 0.002729
# Likelihood of 'text' given spam: 0.003486
# Likelihood of 'text' given ham: 0.000805
# Likelihood of 'get' given spam: 0.002490
# Likelihood of 'get' given ham: 0.003624
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of '87131' given spam: 0.000038
# Likelihood of '87131' given ham: 0.000015
# Likelihood of 'for' given spam: 0.006206
# Likelihood of 'for' given ham: 0.005891
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'true' given spam: 0.000038
# Likelihood of 'true' given ham: 0.000164
# Likelihood of 'tone!' given spam: 0.000038
# Likelihood of 'tone!' given ham: 0.000015
# Likelihood of 'help?' given spam: 0.000153
# Likelihood of 'help?' given ham: 0.000015
# Likelihood of '0845' given spam: 0.000077
# Likelihood of '0845' given ham: 0.000015
# Likelihood of '2814032' given spam: 0.000038
# Likelihood of '2814032' given ham: 0.000015
# Likelihood of '16' given spam: 0.000766
# Likelihood of '16' given ham: 0.000030
# Likelihood of 'after' given spam: 0.000192
# Likelihood of 'after' given ham: 0.001044
# Likelihood of '1st' given spam: 0.000805
# Likelihood of '1st' given ham: 0.000149
# Likelihood of 'free,' given spam: 0.000077
# Likelihood of 'free,' given ham: 0.000045
# Likelihood of 'tones' given spam: 0.000919
# Likelihood of 'tones' given ham: 0.000015
# Likelihood of 'are' given spam: 0.002528
# Likelihood of 'are' given ham: 0.004967
# Likelihood of '3x£150pw' given spam: 0.000038
# Likelihood of '3x£150pw' given ham: 0.000015
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'e£nd' given spam: 0.000038
# Likelihood of 'e£nd' given ham: 0.000015
# Likelihood of 'txt' given spam: 0.003984
# Likelihood of 'txt' given ham: 0.000164
# Likelihood of 'stop' given spam: 0.002988
# Likelihood of 'stop' given ham: 0.000433
# Posterior probabilities for message 'FREE RINGTONE text FIRST to 87131 for a poly or text GET to 87131 for a true tone! Help? 0845 2814032 16 after 1st free, tones are 3x£150pw to e£nd txt stop':
# P(spam|message) = 1.000000
# P(ham|message) = 0.000000
#
# Likelihood of 'sir,' given spam: 0.000038
# Likelihood of 'sir,' given ham: 0.000149
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'am' given spam: 0.000421
# Likelihood of 'am' given ham: 0.002461
# Likelihood of 'waiting' given spam: 0.000575
# Likelihood of 'waiting' given ham: 0.000462
# Likelihood of 'for' given spam: 0.006206
# Likelihood of 'for' given ham: 0.005891
# Likelihood of 'your' given spam: 0.008198
# Likelihood of 'your' given ham: 0.004967
# Likelihood of 'call.' given spam: 0.000115
# Likelihood of 'call.' given ham: 0.000119
# Posterior probabilities for message 'Sir, i am waiting for your call.':
# P(spam|message) = 0.000651
# P(ham|message) = 0.999349
#
# Likelihood of 'crazy' given spam: 0.000192
# Likelihood of 'crazy' given ham: 0.000089
# Likelihood of 'ar' given spam: 0.000038
# Likelihood of 'ar' given ham: 0.000015
# Likelihood of 'he's' given spam: 0.000038
# Likelihood of 'he's' given ham: 0.000343
# Likelihood of 'married.' given spam: 0.000038
# Likelihood of 'married.' given ham: 0.000015
# Likelihood of 'ü' given spam: 0.000038
# Likelihood of 'ü' given ham: 0.001969
# Likelihood of 'like' given spam: 0.000498
# Likelihood of 'like' given ham: 0.002580
# Likelihood of 'gd' given spam: 0.000038
# Likelihood of 'gd' given ham: 0.000164
# Likelihood of 'looking' given spam: 0.000230
# Likelihood of 'looking' given ham: 0.000194
# Likelihood of 'guys' given spam: 0.000153
# Likelihood of 'guys' given ham: 0.000298
# Likelihood of 'not' given spam: 0.000690
# Likelihood of 'not' given ham: 0.004907
# Likelihood of 'me.' given spam: 0.000230
# Likelihood of 'me.' given ham: 0.001119
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'frens' given spam: 0.000038
# Likelihood of 'frens' given ham: 0.000089
# Likelihood of 'like' given spam: 0.000498
# Likelihood of 'like' given ham: 0.002580
# Likelihood of 'say' given spam: 0.000077
# Likelihood of 'say' given ham: 0.001044
# Likelihood of 'he's' given spam: 0.000038
# Likelihood of 'he's' given ham: 0.000343
# Likelihood of 'korean' given spam: 0.000038
# Likelihood of 'korean' given ham: 0.000015
# Likelihood of 'leona's' given spam: 0.000038
# Likelihood of 'leona's' given ham: 0.000015
# Likelihood of 'fave' given spam: 0.000038
# Likelihood of 'fave' given ham: 0.000045
# Likelihood of 'but' given spam: 0.000268
# Likelihood of 'but' given ham: 0.004922
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'dun' given spam: 0.000038
# Likelihood of 'dun' given ham: 0.000731
# Likelihood of 'thk' given spam: 0.000038
# Likelihood of 'thk' given ham: 0.000582
# Likelihood of 'he' given spam: 0.000038
# Likelihood of 'he' given ham: 0.001999
# Likelihood of 'is.' given spam: 0.000038
# Likelihood of 'is.' given ham: 0.000089
# Likelihood of 'aft' given spam: 0.000038
# Likelihood of 'aft' given ham: 0.000224
# Likelihood of 'some' given spam: 0.000230
# Likelihood of 'some' given ham: 0.001223
# Likelihood of 'thinking' given spam: 0.000038
# Likelihood of 'thinking' given ham: 0.000224
# Likelihood of 'mayb' given spam: 0.000038
# Likelihood of 'mayb' given ham: 0.000179
# Likelihood of 'most' given spam: 0.000077
# Likelihood of 'most' given ham: 0.000343
# Likelihood of 'prob' given spam: 0.000038
# Likelihood of 'prob' given ham: 0.000134
# Likelihood of 'i'll' given spam: 0.000038
# Likelihood of 'i'll' given ham: 0.002088
# Likelihood of 'go.' given spam: 0.000038
# Likelihood of 'go.' given ham: 0.000060
# Posterior probabilities for message 'Crazy ar he's married. Ü like gd looking guys not me. My frens like say he's korean leona's fave but i dun thk he is. Aft some thinking mayb most prob i'll go.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'hey' given spam: 0.000192
# Likelihood of 'hey' given ham: 0.001044
# Likelihood of 'now' given spam: 0.003141
# Likelihood of 'now' given ham: 0.001760
# Likelihood of 'am' given spam: 0.000421
# Likelihood of 'am' given ham: 0.002461
# Likelihood of 'free' given spam: 0.005861
# Likelihood of 'free' given ham: 0.000612
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'can' given spam: 0.000996
# Likelihood of 'can' given ham: 0.004430
# Likelihood of 'call' given spam: 0.010459
# Likelihood of 'call' given ham: 0.002685
# Likelihood of 'me.' given spam: 0.000230
# Likelihood of 'me.' given ham: 0.001119
# Posterior probabilities for message 'Hey now am free you can call me.':
# P(spam|message) = 0.005602
# P(ham|message) = 0.994398
#
# Likelihood of 'fighting' given spam: 0.000038
# Likelihood of 'fighting' given ham: 0.000060
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'world' given spam: 0.000077
# Likelihood of 'world' given ham: 0.000313
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'easy,' given spam: 0.000230
# Likelihood of 'easy,' given ham: 0.000060
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'either' given spam: 0.000345
# Likelihood of 'either' given ham: 0.000134
# Likelihood of 'win' given spam: 0.001915
# Likelihood of 'win' given ham: 0.000104
# Likelihood of 'or' given spam: 0.006168
# Likelihood of 'or' given ham: 0.002729
# Likelihood of 'lose' given spam: 0.000077
# Likelihood of 'lose' given ham: 0.000209
# Likelihood of 'bt' given spam: 0.000192
# Likelihood of 'bt' given ham: 0.000239
# Likelihood of 'fightng' given spam: 0.000038
# Likelihood of 'fightng' given ham: 0.000045
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'some1' given spam: 0.000038
# Likelihood of 'some1' given ham: 0.000060
# Likelihood of 'who' given spam: 0.001188
# Likelihood of 'who' given ham: 0.000716
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'close' given spam: 0.000115
# Likelihood of 'close' given ham: 0.000164
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'dificult' given spam: 0.000038
# Likelihood of 'dificult' given ham: 0.000045
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'lose' given spam: 0.000077
# Likelihood of 'lose' given ham: 0.000209
# Likelihood of '-' given spam: 0.001762
# Likelihood of '-' given ham: 0.000388
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'lose' given spam: 0.000077
# Likelihood of 'lose' given ham: 0.000209
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'win' given spam: 0.001915
# Likelihood of 'win' given ham: 0.000104
# Likelihood of '-' given spam: 0.001762
# Likelihood of '-' given ham: 0.000388
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'still' given spam: 0.000230
# Likelihood of 'still' given ham: 0.001715
# Likelihood of 'lose.' given spam: 0.000038
# Likelihood of 'lose.' given ham: 0.000045
# Posterior probabilities for message 'Fighting with the world is easy, u either win or lose bt fightng with some1 who is close to u is dificult if u lose - u lose if u win - u still lose.':
# P(spam|message) = 0.000105
# P(ham|message) = 0.999895
#
# Likelihood of 'then' given spam: 0.000230
# Likelihood of 'then' given ham: 0.002222
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'go' given spam: 0.000881
# Likelihood of 'go' given ham: 0.002894
# Likelihood of 'back' given spam: 0.000651
# Likelihood of 'back' given ham: 0.001253
# Likelihood of 'urself' given spam: 0.000038
# Likelihood of 'urself' given ham: 0.000089
# Likelihood of 'lor...' given spam: 0.000038
# Likelihood of 'lor...' given ham: 0.000641
# Posterior probabilities for message 'Then u go back urself lor...':
# P(spam|message) = 0.000023
# P(ham|message) = 0.999977
#
# Likelihood of 'yeah,' given spam: 0.000038
# Likelihood of 'yeah,' given ham: 0.000239
# Likelihood of 'i'll' given spam: 0.000038
# Likelihood of 'i'll' given ham: 0.002088
# Likelihood of 'leave' given spam: 0.000077
# Likelihood of 'leave' given ham: 0.000552
# Likelihood of 'in' given spam: 0.002145
# Likelihood of 'in' given ham: 0.009292
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'couple' given spam: 0.000077
# Likelihood of 'couple' given ham: 0.000119
# Likelihood of 'minutes' given spam: 0.000230
# Likelihood of 'minutes' given ham: 0.000254
# Likelihood of '&amp;' given spam: 0.000038
# Likelihood of '&amp;' given ham: 0.001014
# Likelihood of 'let' given spam: 0.000038
# Likelihood of 'let' given ham: 0.000880
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'know' given spam: 0.000728
# Likelihood of 'know' given ham: 0.002461
# Likelihood of 'when' given spam: 0.000383
# Likelihood of 'when' given ham: 0.003371
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'get' given spam: 0.002490
# Likelihood of 'get' given ham: 0.003624
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'mu' given spam: 0.000038
# Likelihood of 'mu' given ham: 0.000134
# Posterior probabilities for message 'Yeah, I'll leave in a couple minutes &amp; let you know when I get to mu':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'customer' given spam: 0.001188
# Likelihood of 'customer' given ham: 0.000104
# Likelihood of 'place' given spam: 0.000192
# Likelihood of 'place' given ham: 0.000462
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'will' given spam: 0.001417
# Likelihood of 'will' given ham: 0.004102
# Likelihood of 'call' given spam: 0.010459
# Likelihood of 'call' given ham: 0.002685
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Posterior probabilities for message 'Customer place i will call you':
# P(spam|message) = 0.016671
# P(ham|message) = 0.983329
#
# Likelihood of 'err...' given spam: 0.000038
# Likelihood of 'err...' given ham: 0.000015
# Likelihood of 'cud' given spam: 0.000038
# Likelihood of 'cud' given ham: 0.000060
# Likelihood of 'do.' given spam: 0.000038
# Likelihood of 'do.' given ham: 0.000298
# Likelihood of 'i'm' given spam: 0.000268
# Likelihood of 'i'm' given ham: 0.004549
# Likelihood of 'going' given spam: 0.000192
# Likelihood of 'going' given ham: 0.001849
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'at' given spam: 0.000843
# Likelihood of 'at' given ham: 0.004534
# Likelihood of '8pm.' given spam: 0.000038
# Likelihood of '8pm.' given ham: 0.000015
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'haven't' given spam: 0.000077
# Likelihood of 'haven't' given ham: 0.000224
# Likelihood of 'got' given spam: 0.000306
# Likelihood of 'got' given ham: 0.002774
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'way' given spam: 0.000038
# Likelihood of 'way' given ham: 0.000820
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'contact' given spam: 0.001609
# Likelihood of 'contact' given ham: 0.000149
# Likelihood of 'him' given spam: 0.000077
# Likelihood of 'him' given ham: 0.001014
# Likelihood of 'until' given spam: 0.000153
# Likelihood of 'until' given ham: 0.000224
# Likelihood of 'then.' given spam: 0.000038
# Likelihood of 'then.' given ham: 0.000134
# Posterior probabilities for message 'Err... Cud do. I'm going to  at 8pm. I haven't got a way to contact him until then.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'guess' given spam: 0.000230
# Likelihood of 'guess' given ham: 0.000313
# Likelihood of 'that's' given spam: 0.000038
# Likelihood of 'that's' given ham: 0.000656
# Likelihood of 'why' given spam: 0.000268
# Likelihood of 'why' given ham: 0.000701
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 're' given spam: 0.000306
# Likelihood of 're' given ham: 0.000089
# Likelihood of 'worried.' given spam: 0.000038
# Likelihood of 'worried.' given ham: 0.000045
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'must' given spam: 0.000230
# Likelihood of 'must' given ham: 0.000254
# Likelihood of 'know' given spam: 0.000728
# Likelihood of 'know' given ham: 0.002461
# Likelihood of 'that' given spam: 0.000766
# Likelihood of 'that' given ham: 0.005131
# Likelihood of 'there's' given spam: 0.000153
# Likelihood of 'there's' given ham: 0.000239
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'way' given spam: 0.000038
# Likelihood of 'way' given ham: 0.000820
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'body' given spam: 0.000038
# Likelihood of 'body' given ham: 0.000045
# Likelihood of 'repairs' given spam: 0.000038
# Likelihood of 'repairs' given ham: 0.000015
# Likelihood of 'itself.' given spam: 0.000038
# Likelihood of 'itself.' given ham: 0.000030
# Likelihood of 'and' given spam: 0.003754
# Likelihood of 'and' given ham: 0.010112
# Likelihood of 'i'm' given spam: 0.000268
# Likelihood of 'i'm' given ham: 0.004549
# Likelihood of 'quite' given spam: 0.000038
# Likelihood of 'quite' given ham: 0.000403
# Likelihood of 'sure' given spam: 0.000038
# Likelihood of 'sure' given ham: 0.000701
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'shouldn't' given spam: 0.000038
# Likelihood of 'shouldn't' given ham: 0.000075
# Likelihood of 'worry.' given spam: 0.000038
# Likelihood of 'worry.' given ham: 0.000075
# Likelihood of 'we'll' given spam: 0.000077
# Likelihood of 'we'll' given ham: 0.000149
# Likelihood of 'take' given spam: 0.000460
# Likelihood of 'take' given ham: 0.001223
# Likelihood of 'it' given spam: 0.000805
# Likelihood of 'it' given ham: 0.005250
# Likelihood of 'slow.' given spam: 0.000038
# Likelihood of 'slow.' given ham: 0.000045
# Likelihood of 'first' given spam: 0.000230
# Likelihood of 'first' given ham: 0.000552
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'tests,' given spam: 0.000038
# Likelihood of 'tests,' given ham: 0.000015
# Likelihood of 'they' given spam: 0.000498
# Likelihood of 'they' given ham: 0.001238
# Likelihood of 'will' given spam: 0.001417
# Likelihood of 'will' given ham: 0.004102
# Likelihood of 'guide' given spam: 0.000038
# Likelihood of 'guide' given ham: 0.000075
# Likelihood of 'when' given spam: 0.000383
# Likelihood of 'when' given ham: 0.003371
# Likelihood of 'your' given spam: 0.008198
# Likelihood of 'your' given ham: 0.004967
# Likelihood of 'ovulation' given spam: 0.000038
# Likelihood of 'ovulation' given ham: 0.000030
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'then' given spam: 0.000230
# Likelihood of 'then' given ham: 0.002222
# Likelihood of 'just' given spam: 0.002222
# Likelihood of 'just' given ham: 0.003535
# Likelihood of 'relax.' given spam: 0.000038
# Likelihood of 'relax.' given ham: 0.000060
# Likelihood of 'nothing' given spam: 0.000115
# Likelihood of 'nothing' given ham: 0.000298
# Likelihood of 'you've' given spam: 0.000153
# Likelihood of 'you've' given ham: 0.000134
# Likelihood of 'said' given spam: 0.000038
# Likelihood of 'said' given ham: 0.000776
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'reason' given spam: 0.000038
# Likelihood of 'reason' given ham: 0.000104
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'worry' given spam: 0.000038
# Likelihood of 'worry' given ham: 0.000179
# Likelihood of 'but' given spam: 0.000268
# Likelihood of 'but' given ham: 0.004922
# Likelihood of 'i.ll' given spam: 0.000038
# Likelihood of 'i.ll' given ham: 0.000388
# Likelihood of 'keep' given spam: 0.000268
# Likelihood of 'keep' given ham: 0.000805
# Likelihood of 'on' given spam: 0.004482
# Likelihood of 'on' given ham: 0.004549
# Likelihood of 'followin' given spam: 0.000038
# Likelihood of 'followin' given ham: 0.000015
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'up.' given spam: 0.000038
# Likelihood of 'up.' given ham: 0.000209
# Posterior probabilities for message 'I guess that's why you re worried. You must know that there's a way the body repairs itself. And i'm quite sure you shouldn't worry. We'll take it slow. First the tests, they will guide when your ovulation is then just relax. Nothing you've said is a reason to worry but i.ll keep on followin you up.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'this' given spam: 0.002528
# Likelihood of 'this' given ham: 0.002744
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of '2nd' given spam: 0.000613
# Likelihood of '2nd' given ham: 0.000104
# Likelihood of 'time' given spam: 0.000460
# Likelihood of 'time' given ham: 0.001984
# Likelihood of 'we' given spam: 0.001532
# Likelihood of 'we' given ham: 0.003684
# Likelihood of 'have' given spam: 0.003754
# Likelihood of 'have' given ham: 0.005265
# Likelihood of 'tried' given spam: 0.000536
# Likelihood of 'tried' given ham: 0.000075
# Likelihood of '2' given spam: 0.005287
# Likelihood of '2' given ham: 0.003386
# Likelihood of 'contact' given spam: 0.001609
# Likelihood of 'contact' given ham: 0.000149
# Likelihood of 'u.' given spam: 0.000575
# Likelihood of 'u.' given ham: 0.000328
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'have' given spam: 0.003754
# Likelihood of 'have' given ham: 0.005265
# Likelihood of 'won' given spam: 0.001762
# Likelihood of 'won' given ham: 0.000015
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of '£750' given spam: 0.000038
# Likelihood of '£750' given ham: 0.000015
# Likelihood of 'pound' given spam: 0.000230
# Likelihood of 'pound' given ham: 0.000045
# Likelihood of 'prize.' given spam: 0.000460
# Likelihood of 'prize.' given ham: 0.000015
# Likelihood of '2' given spam: 0.005287
# Likelihood of '2' given ham: 0.003386
# Likelihood of 'claim' given spam: 0.003141
# Likelihood of 'claim' given ham: 0.000015
# Likelihood of 'is' given spam: 0.004367
# Likelihood of 'is' given ham: 0.008308
# Likelihood of 'easy,' given spam: 0.000230
# Likelihood of 'easy,' given ham: 0.000060
# Likelihood of 'call' given spam: 0.010459
# Likelihood of 'call' given ham: 0.002685
# Likelihood of '087187272008' given spam: 0.000038
# Likelihood of '087187272008' given ham: 0.000015
# Likelihood of 'now1!' given spam: 0.000038
# Likelihood of 'now1!' given ham: 0.000015
# Likelihood of 'only' given spam: 0.001954
# Likelihood of 'only' given ham: 0.001313
# Likelihood of '10p' given spam: 0.000421
# Likelihood of '10p' given ham: 0.000015
# Likelihood of 'per' given spam: 0.001379
# Likelihood of 'per' given ham: 0.000179
# Likelihood of 'minute.' given spam: 0.000115
# Likelihood of 'minute.' given ham: 0.000015
# Likelihood of 'bt-national-rate.' given spam: 0.000038
# Likelihood of 'bt-national-rate.' given ham: 0.000015
# Posterior probabilities for message 'This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.':
# P(spam|message) = 1.000000
# P(ham|message) = 0.000000
#
# Likelihood of 'k..k.:)congratulation' given spam: 0.000038
# Likelihood of 'k..k.:)congratulation' given ham: 0.000015
# Likelihood of '..' given spam: 0.000038
# Likelihood of '..' given ham: 0.000194
# Posterior probabilities for message 'K..k.:)congratulation ..':
# P(spam|message) = 0.072907
# P(ham|message) = 0.927093
#
# Likelihood of 'its' given spam: 0.000268
# Likelihood of 'its' given ham: 0.002357
# Likelihood of 'not' given spam: 0.000690
# Likelihood of 'not' given ham: 0.004907
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'same' given spam: 0.000077
# Likelihood of 'same' given ham: 0.000477
# Likelihood of 'here.' given spam: 0.000038
# Likelihood of 'here.' given ham: 0.000164
# Likelihood of 'still' given spam: 0.000230
# Likelihood of 'still' given ham: 0.001715
# Likelihood of 'looking' given spam: 0.000230
# Likelihood of 'looking' given ham: 0.000194
# Likelihood of 'for' given spam: 0.006206
# Likelihood of 'for' given ham: 0.005891
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'job.' given spam: 0.000038
# Likelihood of 'job.' given ham: 0.000075
# Likelihood of 'how' given spam: 0.000268
# Likelihood of 'how' given ham: 0.003058
# Likelihood of 'much' given spam: 0.000077
# Likelihood of 'much' given ham: 0.001059
# Likelihood of 'do' given spam: 0.000805
# Likelihood of 'do' given ham: 0.004310
# Likelihood of 'ta's' given spam: 0.000038
# Likelihood of 'ta's' given ham: 0.000015
# Likelihood of 'earn' given spam: 0.000038
# Likelihood of 'earn' given ham: 0.000030
# Likelihood of 'there.' given spam: 0.000038
# ...
# Likelihood of 'credit.' given ham: 0.000015
# Likelihood of 'please' given spam: 0.001609
# Likelihood of 'please' given ham: 0.000895
# Likelihood of 'top' given spam: 0.000498
# Likelihood of 'top' given ham: 0.000075
# Likelihood of 'up' given spam: 0.000613
# Likelihood of 'up' given ham: 0.003013
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'receive' given spam: 0.001073
# Likelihood of 'receive' given ham: 0.000045
# Likelihood of 'the' given spam: 0.006130
# Likelihood of 'the' given ham: 0.013543
# Likelihood of 'service.' given spam: 0.000153
# Likelihood of 'service.' given ham: 0.000015
# Posterior probabilities for message 'Free msg. Sorry, a service you ordered from 81303 could not be delivered as you do not have sufficient credit. Please top up to receive the service.':
# P(spam|message) = 0.995875
# P(ham|message) = 0.004125
#
# Likelihood of 'if' given spam: 0.001149
# Likelihood of 'if' given ham: 0.004131
# Likelihood of 'he' given spam: 0.000038
# Likelihood of 'he' given ham: 0.001999
# Likelihood of 'started' given spam: 0.000077
# Likelihood of 'started' given ham: 0.000209
# Likelihood of 'searching' given spam: 0.000038
# Likelihood of 'searching' given ham: 0.000075
# Likelihood of 'he' given spam: 0.000038
# Likelihood of 'he' given ham: 0.001999
# Likelihood of 'will' given spam: 0.001417
# Likelihood of 'will' given ham: 0.004102
# Likelihood of 'get' given spam: 0.002490
# Likelihood of 'get' given ham: 0.003624
# Likelihood of 'job' given spam: 0.000038
# Likelihood of 'job' given ham: 0.000343
# Likelihood of 'in' given spam: 0.002145
# Likelihood of 'in' given ham: 0.009292
# Likelihood of 'few' given spam: 0.000038
# Likelihood of 'few' given ham: 0.000462
# Likelihood of 'days.he' given spam: 0.000038
# Likelihood of 'days.he' given ham: 0.000030
# Likelihood of 'have' given spam: 0.003754
# Likelihood of 'have' given ham: 0.005265
# Likelihood of 'great' given spam: 0.000383
# Likelihood of 'great' given ham: 0.000880
# Likelihood of 'potential' given spam: 0.000077
# Likelihood of 'potential' given ham: 0.000030
# Likelihood of 'and' given spam: 0.003754
# Likelihood of 'and' given ham: 0.010112
# Likelihood of 'talent.' given spam: 0.000038
# Likelihood of 'talent.' given ham: 0.000030
# Posterior probabilities for message 'If he started searching he will get job in few days.he have great potential and talent.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'arun' given spam: 0.000038
# Likelihood of 'arun' given ham: 0.000030
# Likelihood of 'can' given spam: 0.000996
# Likelihood of 'can' given ham: 0.004430
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'transfr' given spam: 0.000038
# Likelihood of 'transfr' given ham: 0.000015
# Likelihood of 'me' given spam: 0.000690
# Likelihood of 'me' given ham: 0.007204
# Likelihood of 'd' given spam: 0.000115
# Likelihood of 'd' given ham: 0.001134
# Likelihood of 'amt' given spam: 0.000038
# Likelihood of 'amt' given ham: 0.000015
# Posterior probabilities for message 'Arun can u transfr me d amt':
# P(spam|message) = 0.001013
# P(ham|message) = 0.998987
#
# Likelihood of 'free' given spam: 0.005861
# Likelihood of 'free' given ham: 0.000612
# Likelihood of 'entry' given spam: 0.000843
# Likelihood of 'entry' given ham: 0.000015
# Likelihood of 'in' given spam: 0.002145
# Likelihood of 'in' given ham: 0.009292
# Likelihood of '2' given spam: 0.005287
# Likelihood of '2' given ham: 0.003386
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'wkly' given spam: 0.000498
# Likelihood of 'wkly' given ham: 0.000015
# Likelihood of 'comp' given spam: 0.000345
# Likelihood of 'comp' given ham: 0.000030
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'win' given spam: 0.001915
# Likelihood of 'win' given ham: 0.000104
# Likelihood of 'fa' given spam: 0.000115
# Likelihood of 'fa' given ham: 0.000015
# Likelihood of 'cup' given spam: 0.000153
# Likelihood of 'cup' given ham: 0.000060
# Likelihood of 'final' given spam: 0.000345
# Likelihood of 'final' given ham: 0.000045
# Likelihood of 'tkts' given spam: 0.000115
# Likelihood of 'tkts' given ham: 0.000015
# Likelihood of '21st' given spam: 0.000077
# Likelihood of '21st' given ham: 0.000030
# Likelihood of 'may' given spam: 0.000230
# Likelihood of 'may' given ham: 0.000433
# Likelihood of '2005.' given spam: 0.000115
# Likelihood of '2005.' given ham: 0.000015
# Likelihood of 'text' given spam: 0.003486
# Likelihood of 'text' given ham: 0.000805
# Likelihood of 'fa' given spam: 0.000115
# Likelihood of 'fa' given ham: 0.000015
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of '87121' given spam: 0.000153
# Likelihood of '87121' given ham: 0.000015
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'receive' given spam: 0.001073
# Likelihood of 'receive' given ham: 0.000045
# Likelihood of 'entry' given spam: 0.000843
# Likelihood of 'entry' given ham: 0.000015
# Likelihood of 'question(std' given spam: 0.000077
# Likelihood of 'question(std' given ham: 0.000015
# Likelihood of 'txt' given spam: 0.003984
# Likelihood of 'txt' given ham: 0.000164
# Likelihood of 'rate)t&c's' given spam: 0.000077
# Likelihood of 'rate)t&c's' given ham: 0.000015
# Likelihood of 'apply' given spam: 0.000460
# Likelihood of 'apply' given ham: 0.000030
# Likelihood of '08452810075over18's' given spam: 0.000077
# Likelihood of '08452810075over18's' given ham: 0.000015
# Posterior probabilities for message 'Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's':
# P(spam|message) = 1.000000
# P(ham|message) = 0.000000
#
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'was' given spam: 0.000268
# Likelihood of 'was' given ham: 0.002550
# Likelihood of 'up' given spam: 0.000613
# Likelihood of 'up' given ham: 0.003013
# Likelihood of 'all' given spam: 0.000958
# Likelihood of 'all' given ham: 0.002744
# Likelihood of 'night' given spam: 0.000153
# Likelihood of 'night' given ham: 0.000850
# Likelihood of 'too' given spam: 0.000077
# Likelihood of 'too' given ham: 0.000835
# Likelihood of 'worrying' given spam: 0.000038
# Likelihood of 'worrying' given ham: 0.000015
# Likelihood of 'about' given spam: 0.000230
# Likelihood of 'about' given ham: 0.001775
# Likelihood of 'this' given spam: 0.002528
# Likelihood of 'this' given ham: 0.002744
# Likelihood of 'appt.' given spam: 0.000038
# Likelihood of 'appt.' given ham: 0.000015
# Likelihood of 'it's' given spam: 0.000153
# Likelihood of 'it's' given ham: 0.001119
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'shame' given spam: 0.000038
# Likelihood of 'shame' given ham: 0.000045
# Likelihood of 'we' given spam: 0.001532
# Likelihood of 'we' given ham: 0.003684
# Likelihood of 'missed' given spam: 0.000077
# Likelihood of 'missed' given ham: 0.000254
# Likelihood of 'a' given spam: 0.011455
# Likelihood of 'a' given ham: 0.012499
# Likelihood of 'girls' given spam: 0.000230
# Likelihood of 'girls' given ham: 0.000089
# Likelihood of 'night' given spam: 0.000153
# Likelihood of 'night' given ham: 0.000850
# Likelihood of 'out' given spam: 0.001303
# Likelihood of 'out' given ham: 0.001805
# Likelihood of 'with' given spam: 0.003295
# Likelihood of 'with' given ham: 0.003296
# Likelihood of 'quizzes' given spam: 0.000038
# Likelihood of 'quizzes' given ham: 0.000015
# Likelihood of 'popcorn' given spam: 0.000038
# Likelihood of 'popcorn' given ham: 0.000015
# Likelihood of 'and' given spam: 0.003754
# Likelihood of 'and' given ham: 0.010112
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'doing' given spam: 0.000038
# Likelihood of 'doing' given ham: 0.000850
# Likelihood of 'my' given spam: 0.000345
# Likelihood of 'my' given ham: 0.008785
# Likelihood of 'hair.' given spam: 0.000038
# Likelihood of 'hair.' given ham: 0.000045
# Posterior probabilities for message 'I was up all night too worrying about this appt. It's a shame we missed a girls night out with quizzes popcorn and you doing my hair.':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'have' given spam: 0.003754
# Likelihood of 'have' given ham: 0.005265
# Likelihood of '1' given spam: 0.000996
# Likelihood of '1' given ham: 0.000373
# Likelihood of 'new' given spam: 0.002299
# Likelihood of 'new' given ham: 0.000820
# Likelihood of 'message.' given spam: 0.000230
# Likelihood of 'message.' given ham: 0.000149
# Likelihood of 'please' given spam: 0.001609
# Likelihood of 'please' given ham: 0.000895
# Likelihood of 'call' given spam: 0.010459
# Likelihood of 'call' given ham: 0.002685
# Likelihood of '08712400200.' given spam: 0.000038
# Likelihood of '08712400200.' given ham: 0.000015
# Posterior probabilities for message 'You have 1 new message. Please call 08712400200.':
# P(spam|message) = 0.896018
# P(ham|message) = 0.103982
#
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'too...' given spam: 0.000038
# Likelihood of 'too...' given ham: 0.000089
# Posterior probabilities for message 'U too...':
# P(spam|message) = 0.022938
# P(ham|message) = 0.977062
#
# Likelihood of 'then' given spam: 0.000230
# Likelihood of 'then' given ham: 0.002222
# Likelihood of 'why' given spam: 0.000268
# Likelihood of 'why' given ham: 0.000701
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'came' given spam: 0.000077
# Likelihood of 'came' given ham: 0.000313
# Likelihood of 'to' given spam: 0.021032
# Likelihood of 'to' given ham: 0.018883
# Likelihood of 'hostel.' given spam: 0.000038
# Likelihood of 'hostel.' given ham: 0.000030
# Posterior probabilities for message 'Then why you came to hostel.':
# P(spam|message) = 0.000806
# P(ham|message) = 0.999194
#
# Likelihood of 'den' given spam: 0.000038
# Likelihood of 'den' given ham: 0.000358
# Likelihood of 'only' given spam: 0.001954
# Likelihood of 'only' given ham: 0.001313
# Likelihood of 'weekdays' given spam: 0.000038
# Likelihood of 'weekdays' given ham: 0.000015
# Likelihood of 'got' given spam: 0.000306
# Likelihood of 'got' given ham: 0.002774
# Likelihood of 'special' given spam: 0.000268
# Likelihood of 'special' given ham: 0.000358
# Likelihood of 'price...' given spam: 0.000038
# Likelihood of 'price...' given ham: 0.000015
# Likelihood of 'haiz...' given spam: 0.000038
# Likelihood of 'haiz...' given ham: 0.000030
# Likelihood of 'cant' given spam: 0.000192
# Likelihood of 'cant' given ham: 0.000731
# Likelihood of 'eat' given spam: 0.000038
# Likelihood of 'eat' given ham: 0.000373
# Likelihood of 'liao...' given spam: 0.000038
# Likelihood of 'liao...' given ham: 0.000254
# Likelihood of 'cut' given spam: 0.000038
# Likelihood of 'cut' given ham: 0.000164
# Likelihood of 'nails' given spam: 0.000038
# Likelihood of 'nails' given ham: 0.000015
# Likelihood of 'oso' given spam: 0.000038
# Likelihood of 'oso' given ham: 0.000194
# Likelihood of 'muz' given spam: 0.000038
# Likelihood of 'muz' given ham: 0.000149
# Likelihood of 'wait' given spam: 0.000038
# Likelihood of 'wait' given ham: 0.000671
# Likelihood of 'until' given spam: 0.000153
# Likelihood of 'until' given ham: 0.000224
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'finish' given spam: 0.000038
# Likelihood of 'finish' given ham: 0.000462
# Likelihood of 'drivin' given spam: 0.000038
# Likelihood of 'drivin' given ham: 0.000030
# Likelihood of 'wat,' given spam: 0.000038
# Likelihood of 'wat,' given ham: 0.000015
# Likelihood of 'lunch' given spam: 0.000038
# Likelihood of 'lunch' given ham: 0.000403
# Likelihood of 'still' given spam: 0.000230
# Likelihood of 'still' given ham: 0.001715
# Likelihood of 'muz' given spam: 0.000038
# Likelihood of 'muz' given ham: 0.000149
# Likelihood of 'eat' given spam: 0.000038
# Likelihood of 'eat' given ham: 0.000373
# Likelihood of 'wat...' given spam: 0.000038
# Likelihood of 'wat...' given ham: 0.000149
# Posterior probabilities for message 'Den only weekdays got special price... Haiz... Cant eat liao... Cut nails oso muz wait until i finish drivin wat, lunch still muz eat wat... ':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'not' given spam: 0.000690
# Likelihood of 'not' given ham: 0.004907
# Likelihood of 'busy' given spam: 0.000115
# Likelihood of 'busy' given ham: 0.000179
# Likelihood of 'juz' given spam: 0.000038
# Likelihood of 'juz' given ham: 0.000298
# Likelihood of 'dun' given spam: 0.000038
# Likelihood of 'dun' given ham: 0.000731
# Likelihood of 'wan' given spam: 0.000077
# Likelihood of 'wan' given ham: 0.000656
# Likelihood of '2' given spam: 0.005287
# Likelihood of '2' given ham: 0.003386
# Likelihood of 'go' given spam: 0.000881
# Likelihood of 'go' given ham: 0.002894
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'early..' given spam: 0.000038
# Likelihood of 'early..' given ham: 0.000030
# Likelihood of 'hee..' given spam: 0.000038
# Likelihood of 'hee..' given ham: 0.000015
# Posterior probabilities for message 'I not busy juz dun wan 2 go so early.. Hee.. ':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'yes' given spam: 0.000345
# Likelihood of 'yes' given ham: 0.000552
# Likelihood of 'i' given spam: 0.001188
# Likelihood of 'i' given ham: 0.025878
# Likelihood of 'have.' given spam: 0.000038
# Likelihood of 'have.' given ham: 0.000030
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'that's' given spam: 0.000038
# Likelihood of 'that's' given ham: 0.000656
# Likelihood of 'why' given spam: 0.000268
# Likelihood of 'why' given ham: 0.000701
# Likelihood of 'u' given spam: 0.003716
# Likelihood of 'u' given ham: 0.010500
# Likelihood of 'texted.' given spam: 0.000038
# Likelihood of 'texted.' given ham: 0.000030
# Likelihood of 'pshew...missing' given spam: 0.000038
# Likelihood of 'pshew...missing' given ham: 0.000015
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'so' given spam: 0.000728
# Likelihood of 'so' given ham: 0.004624
# Likelihood of 'much' given spam: 0.000077
# Likelihood of 'much' given ham: 0.001059
# Posterior probabilities for message 'Yes i have. So that's why u texted. Pshew...missing you so much':
# P(spam|message) = 0.000000
# P(ham|message) = 1.000000
#
# Likelihood of 'how' given spam: 0.000268
# Likelihood of 'how' given ham: 0.003058
# Likelihood of 'are' given spam: 0.002528
# Likelihood of 'are' given ham: 0.004967
# Likelihood of 'you' given spam: 0.007432
# Likelihood of 'you' given ham: 0.019777
# Likelihood of 'enjoying' given spam: 0.000038
# Likelihood of 'enjoying' given ham: 0.000015
# Likelihood of 'this' given spam: 0.002528
# Likelihood of 'this' given ham: 0.002744
# Likelihood of 'semester?' given spam: 0.000038
# Likelihood of 'semester?' given ham: 0.000015
# Likelihood of 'take' given spam: 0.000460
# Likelihood of 'take' given ham: 0.001223
# Likelihood of 'care' given spam: 0.000153
# Likelihood of 'care' given ham: 0.000522
# Likelihood of 'brother.' given spam: 0.000038
# Likelihood of 'brother.' given ham: 0.000060
# Posterior probabilities for message 'How are you enjoying this semester? Take care brother.':
# P(spam|message) = 0.001118
# P(ham|message) = 0.998882
#
# Likelihood of 'g.w.r' given spam: 0.000038
# Likelihood of 'g.w.r' given ham: 0.000015
# Posterior probabilities for message 'G.W.R':
# P(spam|message) = 0.284705
# P(ham|message) = 0.715295
#
# Accuracy: 0.97
# Precision: 0.8642
# Recall: 0.9396
# F1-Score: 0.9003
# C:\Users\getac\AppData\Local\Temp\ipykernel_12048\79053486.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   posterior_spam = np.exp(spam_prob) / (np.exp(spam_prob) + np.exp(ham_prob))
# C:\Users\getac\AppData\Local\Temp\ipykernel_12048\79053486.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   posterior_ham = np.exp(ham_prob) / (np.exp(spam_prob) + np.exp(ham_prob))
